# %%
import pandas as pd
from tabulate  import tabulate

ROOT = '../'
RAW_PATH = f'{ROOT}/raw'
DOC_PATH = f'{ROOT}/docs'

# %%
filename = 'papers_original_filtered_DG'

# %%
df = pd.read_csv(f'{RAW_PATH}/{filename}.csv', encoding="utf-8", engine='python')
df.reset_index(inplace=True)
df.rename(columns={'index':'ID'}, inplace=True)
df.head()
# Out:
#    ID                                            Authors  \
# 0   0  Karhapää P., Behutiye W., Rodríguez P., Oivo M...
# 1   1              Pecorelli F., Palomba F., De Lucia A.
# 2   2              Trautsch A., Herbold S., Grabowski J.
# 3   3                                           Alami A.
# 4   4            Kavalchuk A., Goldenberg A., Hussain I.
#
#                                                Title  Year  \
# 0  Strategies to manage quality requirements in a...  2021
# 1  The Relation of Test-Related Factors to Softwa...  2021
# 2  A longitudinal study of static analysis warnin...  2020
# 3  The sustainability of quality in free and open...  2020
# 4  An empirical study of teaching qualities of po...  2020
#
#                                         Source title  \
# 0                     Empirical Software Engineering
# 1                     Empirical Software Engineering
# 2                     Empirical Software Engineering
# 3  Proceedings - International Conference on Soft...
# 4  Proceedings - International Conference on Soft...
#
#                                                 Link  \
# 0  https://www.scopus.com/inward/record.uri?eid=2...
# 1  https://www.scopus.com/inward/record.uri?eid=2...
# 2  https://www.scopus.com/inward/record.uri?eid=2...
# 3  https://www.scopus.com/inward/record.uri?eid=2...
# 4  https://www.scopus.com/inward/record.uri?eid=2...
#
#                                             Abstract
# 0  Agile methods can deliver software that fulfil...
# 1  Testing represents a crucial activity to ensur...
# 2  Automated static analysis tools (ASATs) have b...
# 3  We learned from the history of software that g...
# 4  The employment opportunity for Computer Scienc...

# %%
def add_link(title, link):
    return f'[{title}]({link})'
df.insert(2, 'Linkable_Title', df.apply(lambda x: add_link(x['Title'], x['Link']), axis=1))
df.head()
# Out:
#    ID                                            Authors  \
# 0   0  Karhapää P., Behutiye W., Rodríguez P., Oivo M...
# 1   1              Pecorelli F., Palomba F., De Lucia A.
# 2   2              Trautsch A., Herbold S., Grabowski J.
# 3   3                                           Alami A.
# 4   4            Kavalchuk A., Goldenberg A., Hussain I.
#
#                                       Linkable_Title  \
# 0  [Strategies to manage quality requirements in ...
# 1  [The Relation of Test-Related Factors to Softw...
# 2  [A longitudinal study of static analysis warni...
# 3  [The sustainability of quality in free and ope...
# 4  [An empirical study of teaching qualities of p...
#
#                                                Title  Year  \
# 0  Strategies to manage quality requirements in a...  2021
# 1  The Relation of Test-Related Factors to Softwa...  2021
# 2  A longitudinal study of static analysis warnin...  2020
# 3  The sustainability of quality in free and open...  2020
# 4  An empirical study of teaching qualities of po...  2020
#
#                                         Source title  \
# 0                     Empirical Software Engineering
# 1                     Empirical Software Engineering
# 2                     Empirical Software Engineering
# 3  Proceedings - International Conference on Soft...
# 4  Proceedings - International Conference on Soft...
#
#                                                 Link  \
# 0  https://www.scopus.com/inward/record.uri?eid=2...
# 1  https://www.scopus.com/inward/record.uri?eid=2...
# 2  https://www.scopus.com/inward/record.uri?eid=2...
# 3  https://www.scopus.com/inward/record.uri?eid=2...
# 4  https://www.scopus.com/inward/record.uri?eid=2...
#
#                                             Abstract
# 0  Agile methods can deliver software that fulfil...
# 1  Testing represents a crucial activity to ensur...
# 2  Automated static analysis tools (ASATs) have b...
# 3  We learned from the history of software that g...
# 4  The employment opportunity for Computer Scienc...

# %%
cols=df.columns
#|:--- | :--- | :--- | :--- | :--- | :--- | :---|

df2=pd.DataFrame([[':--- ',' :--- ',' :--- ',' :--- ',' :--- ',' :--- ',' :--- ',' :--- ']], columns=cols)

# %%
df3 = pd.concat([df2,df])
df3.drop(['Title','Link'], axis=1, inplace=True)
df3.to_csv(f'{DOC_PATH}/{filename}.md', sep='|', index=False)
