# %%
import pandas as pd
from tabulate  import tabulate

ROOT = '../'
RAW_PATH = f'{ROOT}/raw'
DOC_PATH = f'{ROOT}/docs'

# %%
#filename = 'papers_original_filtered_DG'
filename = 'papers_original'

# %%
df = pd.read_csv(f'{RAW_PATH}/{filename}.csv', encoding="utf-8", engine='python')
df.reset_index(inplace=True)
df.rename(columns={'index':'ID'}, inplace=True)
df.head()
# Out:
#    ID                                    Authors  \
# 0   0  Griva A., Byrne S., Dennehy D., Conboy K.
# 1   1                    Güdemann M., Mariani L.
# 2   2                      Morales Trujillo M.E.
# 3   3                                Raghavan P.
# 4   4                                  Ozkaya I.
#
#                                                Title  Year  \
# 0  Software Requirements Quality: Using Analytics...  2022
# 1  Preface to the special issue on improving soft...  2021
# 2    Learning Software Quality Assurance with Bricks  2021
# 3           James Smith on Software Bugs and Quality  2021
# 4            Can We Really Achieve Software Quality?  2021
#
#                                         Source title  \
# 0                                      IEEE Software
# 1                           Software Quality Journal
# 2  Proceedings - International Conference on Soft...
# 3                                      IEEE Software
# 4                                      IEEE Software
#
#                                                 Link  \
# 0  https://www.scopus.com/inward/record.uri?eid=2...
# 1  https://www.scopus.com/inward/record.uri?eid=2...
# 2  https://www.scopus.com/inward/record.uri?eid=2...
# 3  https://www.scopus.com/inward/record.uri?eid=2...
# 4  https://www.scopus.com/inward/record.uri?eid=2...
#
#                                             Abstract
# 0  Creating high-quality software requirements is...
# 1  This special issue is dedicated to the present...
# 2  Software Quality Assurance (SQA) and Software ...
# 3                            [No abstract available]
# 4                            [No abstract available]

# %%
def add_link(title, link):
    return f'[{title}]({link})'
df.insert(2, 'Linkable_Title', df.apply(lambda x: add_link(x['Title'], x['Link']), axis=1))
df.head()
# Out:
#    ID                                    Authors  \
# 0   0  Griva A., Byrne S., Dennehy D., Conboy K.
# 1   1                    Güdemann M., Mariani L.
# 2   2                      Morales Trujillo M.E.
# 3   3                                Raghavan P.
# 4   4                                  Ozkaya I.
#
#                                       Linkable_Title  \
# 0  [Software Requirements Quality: Using Analytic...
# 1  [Preface to the special issue on improving sof...
# 2  [Learning Software Quality Assurance with Bric...
# 3  [James Smith on Software Bugs and Quality](htt...
# 4  [Can We Really Achieve Software Quality?](http...
#
#                                                Title  Year  \
# 0  Software Requirements Quality: Using Analytics...  2022
# 1  Preface to the special issue on improving soft...  2021
# 2    Learning Software Quality Assurance with Bricks  2021
# 3           James Smith on Software Bugs and Quality  2021
# 4            Can We Really Achieve Software Quality?  2021
#
#                                         Source title  \
# 0                                      IEEE Software
# 1                           Software Quality Journal
# 2  Proceedings - International Conference on Soft...
# 3                                      IEEE Software
# 4                                      IEEE Software
#
#                                                 Link  \
# 0  https://www.scopus.com/inward/record.uri?eid=2...
# 1  https://www.scopus.com/inward/record.uri?eid=2...
# 2  https://www.scopus.com/inward/record.uri?eid=2...
# 3  https://www.scopus.com/inward/record.uri?eid=2...
# 4  https://www.scopus.com/inward/record.uri?eid=2...
#
#                                             Abstract
# 0  Creating high-quality software requirements is...
# 1  This special issue is dedicated to the present...
# 2  Software Quality Assurance (SQA) and Software ...
# 3                            [No abstract available]
# 4                            [No abstract available]

# %%
cols=df.columns
df2=pd.DataFrame([[':--- ',' :--- ',' :--- ',' :--- ',' :--- ',' :--- ',' :--- ',' :--- ']], columns=cols)

# %%
df3 = pd.concat([df2,df])
df3.drop(['Title','Link'], axis=1, inplace=True)
df3.to_csv(f'{DOC_PATH}/{filename}.md', sep='|', index=False)
